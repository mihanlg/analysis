# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
plt.figure(); df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = pd.Series(list(range(len(df))))
df3.plot(x='A', y='B')

# %%
plt.figure();
df.ix[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df = pd.DataFrame()
df.plot.
# Out:
#   File "<ipython-input-9-a994fc656f61>", line 2
#     df.plot.
#             ^
# SyntaxError: invalid syntax

# %%
plt.figure();
df.ix[5].plot.bar(kind="bar"); plt.axhline(0, color='k')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b06cc58a4776> in <module>()
#       1 plt.figure();
# ----> 2 df.ix[5].plot.bar(kind="bar"); plt.axhline(0, color='k')
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in bar(self, **kwds)
#    3530         axes : matplotlib.AxesSubplot or np.array of them
#    3531         """
# -> 3532         return self(kind='bar', **kwds)
#    3533
#    3534     def barh(self, **kwds):
#
# TypeError: SeriesPlotMethods object got multiple values for keyword argument 'kind'

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-79cb297cb03b> in <module>()
# ----> 1 df2.plot.bar(stacked=True);
#
# NameError: name 'df2' is not defined

# %%
df2.plot.barh(stacked=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c036c487835d> in <module>()
# ----> 1 df2.plot.barh(stacked=True);
#
# NameError: name 'df2' is not defined

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
plt.figure();
df4.plot.hist(alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-04d7a3c5a39d> in <module>()
#       1 df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
#       2 plt.figure();
# ----> 3 df4.plot.hist(alpha=0.5)
#
# AttributeError: 'function' object has no attribute 'hist'

# %%
plt.figure();
df4.plot.hist(stacked=True, bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a615d3e55b62> in <module>()
#       1 plt.figure();
# ----> 2 df4.plot.hist(stacked=True, bins=20)
#
# AttributeError: 'function' object has no attribute 'hist'

# %%
plt.figure();

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8723cae3761d> in <module>()
# ----> 1 df4['a'].plot.hist(orientation='horizontal', cumulative=True)
#
# AttributeError: 'function' object has no attribute 'hist'

# %%
plt.figure();
df['A'].diff().hist()

# %%
plt.figure()
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB117F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DE806A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF464E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D3CD2E8>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E1EABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB07780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000EC34470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000ED5A668>]], dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot(kind="box")

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')
df.plot(kind="box", color=color, sym='r+')

# %%
df.plot(kind="box", vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10,5))
plt.figure();
bp = df.boxplot()
# Out:
# C:\Anaconda\lib\site-packages\pandas\tools\plotting.py:2633: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %%
df = pd.DataFrame(np.random.rand(10,2), columns=['Col1', 'Col2'] )
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
plt.figure();
bp = df.boxplot(by='X')

# %%
df = pd.DataFrame(np.random.rand(10,3), columns=['Col1', 'Col2', 'Col3'])
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df['Y'] = pd.Series(['A','B','A','B','A','B','A','B','A','B'])
plt.figure();
bp = df.boxplot(column=['Col1','Col2'], by=['X','Y'])

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A', 'B'], size=50)
df_box.loc[df_box['g'] == 'B', 1] += 3
bp = df_box.boxplot(by='g')

# %%
bp = df_box.groupby('g').boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot(kind="area");

# %%
df.plot(kind="area", stacked=False);

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot(kind="scatter", x='a', y='b');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
df.plot(kind="scatter", x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot(kind="scatter", x='a', y='b', c='c', s=50);

# %%
df.plot(kind="scatter", x='a', y='b', s=df['c']*200);

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series.plot(kind="pie", figsize=(6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
df.plot(kind="pie", subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001299A0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012B3E320>], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000115EB2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000118CC5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011992B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012496DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001112F898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011FA56D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011F36208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011678A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011785550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000126B6F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000113E3D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012765898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000129F90F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011736C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000116BD3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000130488D0>]], dtype=object)

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot(kind="kde")
